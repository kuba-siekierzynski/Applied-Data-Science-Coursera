# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **sports or athletics** (see below) for the region of **Warsaw, Mazovia, Poland**, or **Poland** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Warsaw, Mazovia, Poland** to Ann Arbor, USA. In that case at least one source file must be about **Warsaw, Mazovia, Poland**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Warsaw, Mazovia, Poland** and **sports or athletics**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **sports or athletics**?  For this category we are interested in sporting events or athletics broadly, please feel free to creatively interpret the category when building your research question!
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %% [markdown]
# <hr>

# %% [markdown]
# # Becoming an independent Data Scientist - final assignment

# %% [markdown]
# ### Identifying the problem - Sports activities in Poland - which regions are more sporty than others?

# %% [markdown]
# When thinking of an assignment that would cover the **sports and athletics** topic, I browsed through what the Polish Stat Office had at its disposal. I found that they had statistics of people officially (in a registered way) practising sports - in sport clubs, communities, league teams and school clubs.<br><br>
# What was more important - the data was fragmentable down to the level of a town or commune. While that was tempting but probably hard to visualize and to grasp the concept, I decided to stop at the poviat level (poviats compose larger structures - voivodships - and may either be a group of communes or particular cities (usually large ones) act as poviats on their own.<br><br>
# We have 380 poviats altogether in Poland, counting with the cities. What I found was that since 2002 the Stat Office carries out its statistics every second year, so we have eight periods of observation. Now the question is - **are there some particularly sporty areas in Poland?**<br><br>
# *Be my guest and check that for yourself! :)*

# %% [markdown]
# ### Combining datasets - Sports trends in Poland

# %% [markdown]
# I chose three different datasets I pull information from:
#   1. The list of Polish regions (voivodships and poviats) along with their population - wikipedia
#   2. The data on people practising sports by voivodships and poviats in 2002-2016 - Główny Urząd Statystyczny (Polish Stat Office)
#   3. Geolocation data - Google API
#
# What the code does is:
#   1. It retrieves a list of Polish poviats and their population count and saves that.
#   2. It then iteratively asks Google geolocation API for longitude/latitude of poviats and stores those coordinates.
#   3. Then, it looks for the data on people practising sports per poviats.
#   4. Finally, it displays a scatter plot with longitude and latitude of poviats as x and y and the population count as radius.
#   5. The shade of a bubble is dependent on the share of people practising sports in the total population of the poviat.
#   6. It then allows the user to use a slider and change the YEAR of the scatter plot

# %% [markdown]
# ### 1. Get the data on sports activities from Statistics Poland

# %% [markdown]
# The Polish statistical office - Statistics Poland (www.stat.gov.pl) - publishes its data on its platform Bank Danych Lokalnych (Local Data Bank): https://bdl.stat.gov.pl/BDL/start
# The JavaScript based platform allows for procuring the datasets tailored to the user's needs. However, for my assignment it still needed some minor cleaning afterwards.
# I downloaded it to the local file: KULT_2155_XTAB_20180331131428.xlsx and left it intact.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# Load the data from a downloaded file available and procured from Statistics Poland (www.stat.gov.pl) and put on my github
yrs = [str(2002+i*2) for i in range(8)] # '2002'-'2016'

import urllib.request

url = 'https://github.com/kuba-siekierzynski/Applied-Data-Science-Coursera/files/1866674/KULT_2155_XTAB_20180331131428.xlsx'

with urllib.request.urlopen(url) as f:
    poviats1 = pd.read_excel('KULT_2155_XTAB_20180331131428.xlsx',sheetname='TABLICA',
                             header=None, skiprows=4, parse_cols='A,B,F,G,H,I,J,K,L,M',
                             names=['TERYT', 'Name'] + yrs, dtype='str')

# Adding voivodship information for future disambiguation
voivodships = poviats1[poviats1['TERYT'].astype(str).str.endswith('00000')][['TERYT', 'Name']] # retreive the voivodships
poviats1['TERYT'] = poviats1['TERYT'].str[:2]
voivodships['TERYT'] = voivodships['TERYT'].str[:2]
voivodships = voivodships.rename(columns={'Name': 'Voivodship'})
poviats1 = poviats1.merge(voivodships, how='left', on='TERYT')
poviats1['Voivodship'] = poviats1['Voivodship'].str.lower() # poviats1 will store the voivodship in additional columns

# now some tidying up...
poviats1 = poviats1[poviats1['Name'].astype('str').str.startswith('Powiat')] # filter for regional data only
poviats1[yrs] = poviats1[yrs].replace('-', 0).astype(np.int32)

# Wałbrzych was a separate poviat until 2002 and then again since 2014, but we need it only once
poviats1.loc[310, '2002'] = poviats1.loc[307, '2002']
poviats1.drop(307, inplace=True) # obsolete - Wałbrzych until 2002
poviats1.loc[310, 'Name'] = 'Wałbrzych' # rename to the proper city name
poviats1.loc[1979, 'Name'] = 'Warszawa' # drop the 'capital city of' part
poviats1['Name'] = poviats1['Name'].str.replace(r'Powiat m\.', '') # for cities as municipality centers - drop the redundant part
poviats1.drop('TERYT', axis=1, inplace=True)
poviats1
# Out:
#                        Name   2002   2004   2006   2008   2010   2012   2014  \
# 1      Powiat bolesławiecki   1650   1842   2129   1785   2113   1900   1847
# 10    Powiat dzierżoniowski   1242   2262   2670   2353   2511   2570   3144
# 23         Powiat głogowski   1369   1279   1628   1336   2098   1820   2426
# 30          Powiat górowski    481    648    652    642    315    393    531
# 38          Powiat jaworski    669    820    929   1051   1316   1332   1328
# 47     Powiat jeleniogórski   1027   1240   1624   1481   1135   1285   1256
# 57    Powiat kamiennogórski    581    873   1181   1073   1082   1125   1044
# 64           Powiat kłodzki   2827   2759   3325   3255   3613   3505   4196
# 91          Powiat legnicki    759    615   1193   1120   1026   1348   1587
# 102         Powiat lubański    550    659    904    838   1261   1378   1489
# 113         Powiat lubiński   1899   1986   1796   1612   1728   2476   2192
# 120         Powiat lwówecki    845   1170    863   2633    870   1236   1052
# 136          Powiat milicki    734    854    746    658    796    736    811
# 142        Powiat oleśnicki   1746   1996   1350   2019   1672   2397   2315
# 158          Powiat oławski    720    513    876    882    916   1806   1623
# 165       Powiat polkowicki   1517    998   1507   1073   1442   1967   2428
# 178      Powiat strzeliński    362   1099   1203   1102   1090   1260   1328
# 188          Powiat średzki    415    508    545    948    834   1279   1352
# 196        Powiat świdnicki   1615   3078   3271   2851   4007   4481   5031
# 211       Powiat trzebnicki    755    984   1708   1439   1754   1863   2339
# 226       Powiat wałbrzyski    550   1936   3160   3090   2606   3282   1661
# 240         Powiat wołowski   1111   1678   1171   1322   1394   1343   1364
# 248       Powiat wrocławski   1774   2278   2861   2222   2355   3603   4065
# 264       Powiat ząbkowicki    667   1059    689   1117   1370   1620   1896
# 280      Powiat zgorzelecki   1990   1753   2592   2335   2469   2905   2413
# 294      Powiat złotoryjski    884    774   1036   1234   1504   1753   1617
# 303            Jelenia Góra   2273   2883   3495   2112   2323   2391   2690
# 305                 Legnica   2285   2449   2391   1759   2005   2135   2119
# 308                 Wrocław  12799  11372  13747  13731  14254  15392  16433
# 310               Wałbrzych   1527      0      0      0      0      0   1871
# 3756   1839       wielkopolskie
# 3762   1579       wielkopolskie
# 3776   1797       wielkopolskie
# 3791   2536       wielkopolskie
# 3793   2382       wielkopolskie
# 3795   1715       wielkopolskie
# 3797  15228       wielkopolskie
# 3800    736  zachodniopomorskie
# 3810   2097  zachodniopomorskie
# 3825   1654  zachodniopomorskie
# 3838   1285  zachodniopomorskie
# 3854   1503  zachodniopomorskie
# 3867   2208  zachodniopomorskie
# 3888   1935  zachodniopomorskie
# 3905   2157  zachodniopomorskie
# 3916   1483  zachodniopomorskie
# 3931   1540  zachodniopomorskie
# 3943   1626  zachodniopomorskie
# 3949    758  zachodniopomorskie
# 3959   1380  zachodniopomorskie
# 3966   3910  zachodniopomorskie
# 3983   3177  zachodniopomorskie
# 3995   1670  zachodniopomorskie
# 4004   1445  zachodniopomorskie
# 4015   1348  zachodniopomorskie
# 4027   3133  zachodniopomorskie
# 4029  11958  zachodniopomorskie
# 4031    578  zachodniopomorskie
#
# [380 rows x 10 columns]

# %% [markdown]
# <hr>

# %% [markdown]
# ### 2. Get the population numbers for poviats from Wikipedia

# %% [markdown]
# The most easily accessible is parsing the Wikipedia page on Polish poviat statistics. This will also ensure that we have the latest information - administration division might have changed between years. The page we are looking for is: https://pl.wikipedia.org/wiki/Powiaty_w_Polsce

# %%
# let's get ready for some parsing
from bs4 import BeautifulSoup

# %%
# accessing the url and parsing it to the beautifulsoup object 'soup'
url = 'https://pl.wikipedia.org/wiki/Powiaty_w_Polsce'
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')
table_rows = soup.find_all('table')[2].find_all('tr') # the data is in the third table on the page

# %%
# collecting the data to a dictionary, which keys are poviat names and values - population
poviats2 = {}
for row in table_rows:
    pov_data = []
    pov_key = row.a['title'] # find the poviat name
    pov_voi = row.find_all('a')[1].text # find the voivodship
    pov_number = row.find_next('td').find_next_sibling('td', attrs={'class': 'tabela-liczba'}).find_next_sibling('td', attrs={'class': 'tabela-liczba'}).text
    poviats2[pov_key] = pov_voi, int(str(pov_number).replace('\xa0', ''))

# convert to DataFrame and clean
poviats2 = pd.DataFrame(poviats2)
poviats2 = poviats2.T.reset_index()
poviats2.columns = ['Name', 'Voivodship', 'Population']
poviats2.drop(35, inplace=True)
poviats2
# Out:
#                      Name           Voivodship Population
# 0          Biała Podlaska            lubelskie      57303
# 1               Białystok            podlaskie     296628
# 2           Bielsko-Biała              śląskie     172030
# 3               Bydgoszcz   kujawsko-pomorskie     353938
# 4                   Bytom              śląskie     169617
# 5                   Chełm            lubelskie      63734
# 6                 Chorzów              śląskie     109398
# 7             Częstochowa              śląskie     226225
# 8        Dąbrowa Górnicza              śląskie     121802
# 9                  Elbląg  warmińsko-mazurskie     121191
# 10                 Gdańsk            pomorskie     463754
# 11                 Gdynia            pomorskie     246991
# 12                Gliwice              śląskie     182156
# 13    Gorzów Wielkopolski             lubuskie     123995
# 14              Grudziądz   kujawsko-pomorskie      95964
# 15       Jastrzębie-Zdrój              śląskie      89883
# 16               Jaworzno              śląskie      92473
# 17           Jelenia Góra         dolnośląskie      80524
# 286       Powiat tomaszowski (województwo łódzkie)        łódzkie     118234
# 336      Powiat średzki (województwo dolnośląskie)   dolnośląskie      53181
# 337     Powiat średzki (województwo wielkopolskie)  wielkopolskie      57691
# 339    Powiat świdnicki (województwo dolnośląskie)   dolnośląskie     158939
# 340       Powiat świdnicki (województwo lubelskie)      lubelskie      72495

# %% [markdown]
# <hr>

# %% [markdown]
# ### 3. Getting geolocation data from Google API

# %% [markdown]
# Since we already have the poviat names listed and those names of which occur multiple times still have the voivodship data, let's look for geolocation coordinates. Google API allows for 2,500 free queries per day, so we have to be careful :)

# %%
# even more parsing...
from urllib.parse import urlencode as ENCODE
from xml.etree import ElementTree as XML

# geo_pov will store geolocation data for poviats
geo_pov = {}

# %%
def localize(poviat):
    """
    Takes a poviat name, pushes it to Google API and assigns latitude and longitude to the geo_pov item
    """
    global geo_pov
    api_url = 'http://maps.googleapis.com/maps/api/geocode/xml?'
    # the location of Google's geolocation API
    url = api_url + ENCODE({'sensor': 'false', 'address': poviat + ', Poland'})
    # putting the parts together in UTF-8 format
    f = False
    while not f:
        print('Retrieving the data on:', poviat)
        data = urllib.request.urlopen(url).read()
        # getting that data
        print('Retrieved', len(data), 'characters. Parsing...')
        tree = XML.fromstring(data)
        # digging into the XML tree
        res = tree.findall('result')
        # let's see the results now
        if len(res) > 0:
            f = True
        else:
            print('Something went wrong, trying again.') # this happens a lot, as too hasty requests may cause Google to block
    lat = res[0].find('geometry').find('location').find('lat').text
    # dig into the XML tree to find 'latitude'
    lng = res[0].find('geometry').find('location').find('lng').text
    # and longitude
    lat = float(lat)
    lng = float(lng)
    geo_pov[poviat] = lat, lng # add the coordinates to the geo_pov dictionary - latitude first, longitude second

# %% [markdown]
# <b>The below might take a while, depending on your internet connection!</b>

# %%
# let's go!
for pov in list(poviats2['Name']):
    localize(pov)
# Out:
# Retrieving the data on: Biała Podlaska
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Biała Podlaska
# Retrieved 1747 characters. Parsing...
# Retrieving the data on: Białystok
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Białystok
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Białystok
# Retrieved 1725 characters. Parsing...
# Retrieving the data on: Bielsko-Biała
# Retrieved 1732 characters. Parsing...
# Retrieving the data on: Bydgoszcz
# Retrieved 1766 characters. Parsing...
# Retrieving the data on: Bytom
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Bytom
# Retrieved 1710 characters. Parsing...
# Retrieving the data on: Chełm
# Retrieved 1702 characters. Parsing...
# Retrieving the data on: Chorzów
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Chorzów
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Chorzów
# Retrieved 1722 characters. Parsing...
# Retrieving the data on: Częstochowa
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Częstochowa
# Retrieved 1739 characters. Parsing...
# Retrieving the data on: Dąbrowa Górnicza
# Retrieved 1769 characters. Parsing...
# Retrieving the data on: Elbląg
# Retrieved 1713 characters. Parsing...
# Retrieving the data on: Gdańsk
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Gdańsk
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Gdańsk
# Retrieved 1724 characters. Parsing...
# Retrieving the data on: Gdynia
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Gdynia
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Gdynia
# Retrieved 1719 characters. Parsing...
# Retrieving the data on: Gliwice
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Gliwice
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Gliwice
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Gliwice
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Gliwice
# Retrieved 1734 characters. Parsing...
# Retrieving the data on: Gorzów Wielkopolski
# Retrieved 1756 characters. Parsing...
# Retrieving the data on: Grudziądz
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Grudziądz
# Retrieved 1748 characters. Parsing...
# Retrieving the data on: Jastrzębie-Zdrój
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Jastrzębie-Zdrój
# Retrieved 1775 characters. Parsing...
# Retrieving the data on: Jaworzno
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Jaworzno
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Jaworzno
# Retrieved 1557 characters. Parsing...
# Retrieving the data on: Jelenia Góra
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Jelenia Góra
# Retrieved 1776 characters. Parsing...
# Retrieving the data on: Kalisz
# Retrieved 1741 characters. Parsing...
# Retrieving the data on: Katowice
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Katowice
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Katowice
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Katowice
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Katowice
# Retrieved 1725 characters. Parsing...
# Retrieving the data on: Kielce
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Kielce
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Kielce
# Retrieved 1717 characters. Parsing...
# Retrieving the data on: Konin
# Retrieved 1736 characters. Parsing...
# Retrieving the data on: Koszalin
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Koszalin
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Koszalin
# Retrieved 1753 characters. Parsing...
# Retrieving the data on: Kraków
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Kraków
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Kraków
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Kraków
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Kraków
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Kraków
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Kraków
# Retrieved 1744 characters. Parsing...
# Retrieving the data on: Krosno
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Krosno
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Krosno
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Krosno
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Krosno
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Krosno
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Krosno
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Krosno
# Retrieved 1737 characters. Parsing...
# Retrieving the data on: Legnica
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Legnica
# Retrieved 1746 characters. Parsing...
# Retrieving the data on: Leszno
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Leszno
# Retrieved 1721 characters. Parsing...
# Retrieving the data on: Lublin
# Retrieved 1725 characters. Parsing...
# Retrieving the data on: Mysłowice
# Retrieved 1732 characters. Parsing...
# Retrieving the data on: Nowy Sącz
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Nowy Sącz
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Nowy Sącz
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Nowy Sącz
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Nowy Sącz
# Retrieved 1736 characters. Parsing...
# Retrieving the data on: Olsztyn
# Retrieved 1730 characters. Parsing...
# Retrieving the data on: Opole
# Retrieved 1698 characters. Parsing...
# Retrieving the data on: Ostrołęka
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Ostrołęka
# Retrieved 1748 characters. Parsing...
# Retrieving the data on: Piekary Śląskie
# Retrieved 1764 characters. Parsing...
# Retrieving the data on: Piotrków Trybunalski
# Retrieved 1778 characters. Parsing...
# Retrieving the data on: Powiat aleksandrowski
# Retrieved 1631 characters. Parsing...
# Retrieving the data on: Powiat augustowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat augustowski
# Retrieved 1602 characters. Parsing...
# Retrieving the data on: Powiat bartoszycki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat bartoszycki
# Retrieved 1451 characters. Parsing...
# Retrieving the data on: Powiat bełchatowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat bełchatowski
# Retrieved 1604 characters. Parsing...
# Retrieving the data on: Powiat bialski
# Retrieved 1790 characters. Parsing...
# Retrieving the data on: Powiat białobrzeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat białobrzeski
# Retrieved 1609 characters. Parsing...
# Retrieving the data on: Powiat białogardzki
# Retrieved 1617 characters. Parsing...
# Retrieving the data on: Powiat białostocki
# Retrieved 1398 characters. Parsing...
# Retrieving the data on: Powiat bielski (województwo podlaskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat bielski (województwo podlaskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat bielski (województwo podlaskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat bielski (województwo podlaskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat bielski (województwo podlaskie)
# Retrieved 1425 characters. Parsing...
# Retrieving the data on: Powiat bielski (województwo śląskie)
# Retrieved 1426 characters. Parsing...
# Retrieving the data on: Powiat bieruńsko-lędziński
# Retrieved 1453 characters. Parsing...
# Retrieving the data on: Powiat bieszczadzki
# Retrieved 1443 characters. Parsing...
# Retrieving the data on: Powiat biłgorajski
# Retrieved 1428 characters. Parsing...
# Retrieving the data on: Powiat bocheński
# Retrieved 1604 characters. Parsing...
# Retrieving the data on: Powiat bolesławiecki
# Retrieved 1621 characters. Parsing...
# Retrieving the data on: Powiat braniewski
# Retrieved 1445 characters. Parsing...
# Retrieving the data on: Powiat brodnicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat brodnicki
# Retrieved 1451 characters. Parsing...
# Retrieving the data on: Powiat brzeski (województwo małopolskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat brzeski (województwo małopolskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat brzeski (województwo małopolskie)
# Retrieved 1604 characters. Parsing...
# Retrieving the data on: Powiat brzeski (województwo opolskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat brzeski (województwo opolskie)
# Retrieved 1414 characters. Parsing...
# Retrieving the data on: Powiat brzeziński
# Retrieved 1427 characters. Parsing...
# Retrieving the data on: Powiat brzozowski
# Retrieved 1605 characters. Parsing...
# Retrieving the data on: Powiat buski
# Retrieved 1576 characters. Parsing...
# Retrieving the data on: Powiat bydgoski
# Retrieved 1803 characters. Parsing...
# Retrieving the data on: Powiat bytowski
# Retrieved 1427 characters. Parsing...
# Retrieving the data on: Powiat będziński
# Retrieved 1426 characters. Parsing...
# Retrieving the data on: Powiat chełmiński
# Retrieved 1619 characters. Parsing...
# Retrieving the data on: Powiat chełmski
# Retrieved 1736 characters. Parsing...
# Retrieving the data on: Powiat chodzieski
# Retrieved 1612 characters. Parsing...
# Retrieving the data on: Powiat chojnicki
# Retrieved 1433 characters. Parsing...
# Retrieving the data on: Powiat choszczeński
# Retrieved 1446 characters. Parsing...
# Retrieving the data on: Powiat chrzanowski
# Retrieved 1610 characters. Parsing...
# Retrieving the data on: Powiat ciechanowski
# Retrieved 1603 characters. Parsing...
# Retrieving the data on: Powiat cieszyński
# Retrieved 1426 characters. Parsing...
# Retrieving the data on: Powiat czarnkowsko-trzcianecki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat czarnkowsko-trzcianecki
# Retrieved 1642 characters. Parsing...
# Retrieving the data on: Powiat częstochowski
# Retrieved 1779 characters. Parsing...
# Retrieving the data on: Powiat człuchowski
# Retrieved 1439 characters. Parsing...
# Retrieving the data on: Powiat drawski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat drawski
# Retrieved 1440 characters. Parsing...
# Retrieving the data on: Powiat działdowski
# Retrieved 1451 characters. Parsing...
# Retrieving the data on: Powiat dzierżoniowski
# Retrieved 1456 characters. Parsing...
# Retrieving the data on: Powiat dąbrowski
# Retrieved 1607 characters. Parsing...
# Retrieving the data on: Powiat dębicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat dębicki
# Retrieved 1434 characters. Parsing...
# Retrieving the data on: Powiat elbląski
# Retrieved 1442 characters. Parsing...
# Retrieving the data on: Powiat ełcki
# Retrieved 1601 characters. Parsing...
# Retrieving the data on: Powiat garwoliński
# Retrieved 1597 characters. Parsing...
# Retrieving the data on: Powiat gdański
# Retrieved 1430 characters. Parsing...
# Retrieving the data on: Powiat giżycki
# Retrieved 1445 characters. Parsing...
# Retrieving the data on: Powiat gliwicki
# Retrieved 1769 characters. Parsing...
# Retrieving the data on: Powiat gnieźnieński
# Retrieved 1606 characters. Parsing...
# Retrieving the data on: Powiat goleniowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat goleniowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat goleniowski
# Retrieved 1614 characters. Parsing...
# Retrieving the data on: Powiat golubsko-dobrzyński
# Retrieved 1637 characters. Parsing...
# Retrieving the data on: Powiat gorlicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat gorlicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat gorlicki
# Retrieved 1436 characters. Parsing...
# Retrieving the data on: Powiat gorzowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat gorzowski
# Retrieved 1791 characters. Parsing...
# Retrieving the data on: Powiat gostyniński
# Retrieved 1429 characters. Parsing...
# Retrieving the data on: Powiat gostyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat gostyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat gostyński
# Retrieved 1606 characters. Parsing...
# Retrieving the data on: Powiat gołdapski
# Retrieved 1442 characters. Parsing...
# Retrieving the data on: Powiat grajewski
# Retrieved 1596 characters. Parsing...
# Retrieving the data on: Powiat grodziski (województwo mazowieckie)
# Retrieved 1630 characters. Parsing...
# Retrieving the data on: Powiat grodziski (województwo wielkopolskie)
# Retrieved 1648 characters. Parsing...
# Retrieving the data on: Powiat grudziądzki
# Retrieved 1786 characters. Parsing...
# Retrieving the data on: Powiat gryficki
# Retrieved 1440 characters. Parsing...
# Retrieving the data on: Powiat gryfiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat gryfiński
# Retrieved 1440 characters. Parsing...
# Retrieving the data on: Powiat grójecki
# Retrieved 1426 characters. Parsing...
# Retrieving the data on: Powiat górowski
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat głogowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat głogowski
# Retrieved 1441 characters. Parsing...
# Retrieving the data on: Powiat głubczycki
# Retrieved 1429 characters. Parsing...
# Retrieving the data on: Powiat hajnowski
# Retrieved 1434 characters. Parsing...
# Retrieving the data on: Powiat hrubieszowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat hrubieszowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat hrubieszowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat hrubieszowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat hrubieszowski
# Retrieved 1434 characters. Parsing...
# Retrieving the data on: Powiat inowrocławski
# Retrieved 1628 characters. Parsing...
# Retrieving the data on: Powiat iławski
# Retrieved 1607 characters. Parsing...
# Retrieving the data on: Powiat janowski
# Retrieved 1614 characters. Parsing...
# Retrieving the data on: Powiat jarociński
# Retrieved 1606 characters. Parsing...
# Retrieving the data on: Powiat jarosławski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat jarosławski
# Retrieved 1608 characters. Parsing...
# Retrieving the data on: Powiat jasielski
# Retrieved 1599 characters. Parsing...
# Retrieving the data on: Powiat jaworski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat jaworski
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat jeleniogórski
# Retrieved 1817 characters. Parsing...
# Retrieving the data on: Powiat jędrzejowski
# Retrieved 1426 characters. Parsing...
# Retrieving the data on: Powiat kaliski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kaliski
# Retrieved 1775 characters. Parsing...
# Retrieving the data on: Powiat kamiennogórski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kamiennogórski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kamiennogórski
# Retrieved 1459 characters. Parsing...
# Retrieving the data on: Powiat kamieński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kamieński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kamieński
# Retrieved 1440 characters. Parsing...
# Retrieving the data on: Powiat kartuski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kartuski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kartuski
# Retrieved 1430 characters. Parsing...
# Retrieving the data on: Powiat kazimierski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kazimierski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kazimierski
# Retrieved 1591 characters. Parsing...
# Retrieving the data on: Powiat kielecki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kielecki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kielecki
# Retrieved 1751 characters. Parsing...
# Retrieving the data on: Powiat kluczborski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kluczborski
# Retrieved 1594 characters. Parsing...
# Retrieving the data on: Powiat kolbuszowski
# Retrieved 1443 characters. Parsing...
# Retrieving the data on: Powiat kolneński
# Retrieved 1422 characters. Parsing...
# Retrieving the data on: Powiat kolski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kolski
# Retrieved 1600 characters. Parsing...
# Retrieving the data on: Powiat konecki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat konecki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat konecki
# Retrieved 1417 characters. Parsing...
# Retrieving the data on: Powiat koniński
# Retrieved 1769 characters. Parsing...
# Retrieving the data on: Powiat koszaliński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat koszaliński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat koszaliński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat koszaliński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat koszaliński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat koszaliński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat koszaliński
# Retrieved 1789 characters. Parsing...
# Retrieving the data on: Powiat kozienicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kozienicki
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kołobrzeski
# Retrieved 1449 characters. Parsing...
# Retrieving the data on: Powiat kościański
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kościański
# Retrieved 1609 characters. Parsing...
# Retrieving the data on: Powiat kościerski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kościerski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kościerski
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kościerski
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kościerski
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kościerski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kościerski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kościerski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kościerski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kościerski
# Retrieved 1445 characters. Parsing...
# Retrieving the data on: Powiat krakowski
# Retrieved 1779 characters. Parsing...
# Retrieving the data on: Powiat krapkowicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krapkowicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krapkowicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krapkowicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krapkowicki
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krapkowicki
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krapkowicki
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krapkowicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krapkowicki
# Retrieved 1429 characters. Parsing...
# Retrieving the data on: Powiat krasnostawski
# Retrieved 1599 characters. Parsing...
# Retrieving the data on: Powiat kraśnicki
# Retrieved 1425 characters. Parsing...
# Retrieving the data on: Powiat krotoszyński
# Retrieved 1612 characters. Parsing...
# Retrieving the data on: Powiat krośnieński (województwo lubuskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krośnieński (województwo lubuskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krośnieński (województwo lubuskie)
# Retrieved 1623 characters. Parsing...
# Retrieving the data on: Powiat krośnieński (województwo podkarpackie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krośnieński (województwo podkarpackie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krośnieński (województwo podkarpackie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat krośnieński (województwo podkarpackie)
# Retrieved 1771 characters. Parsing...
# Retrieving the data on: Powiat kutnowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kutnowski
# Retrieved 1586 characters. Parsing...
# Retrieving the data on: Powiat kwidzyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kwidzyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kwidzyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kwidzyński
# Retrieved 1430 characters. Parsing...
# Retrieving the data on: Powiat kędzierzyńsko-kozielski
# Retrieved 1621 characters. Parsing...
# Retrieving the data on: Powiat kępiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kępiński
# Retrieved 1435 characters. Parsing...
# Retrieving the data on: Powiat kętrzyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kętrzyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kętrzyński
# Retrieved 1613 characters. Parsing...
# Retrieving the data on: Powiat kłobucki
# Retrieved 1429 characters. Parsing...
# Retrieving the data on: Powiat kłodzki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat kłodzki
# Retrieved 1441 characters. Parsing...
# Retrieving the data on: Powiat legionowski
# Retrieved 1600 characters. Parsing...
# Retrieving the data on: Powiat legnicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat legnicki
# Retrieved 1746 characters. Parsing...
# Retrieving the data on: Powiat leski
# Retrieved 1428 characters. Parsing...
# Retrieving the data on: Powiat leszczyński
# Retrieved 1755 characters. Parsing...
# Retrieving the data on: Powiat leżajski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat leżajski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat leżajski
# Retrieved 1605 characters. Parsing...
# Retrieving the data on: Powiat lidzbarski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat lidzbarski
# Retrieved 1613 characters. Parsing...
# Retrieving the data on: Powiat limanowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat limanowski
# Retrieved 1607 characters. Parsing...
# Retrieving the data on: Powiat lipnowski
# Retrieved 1610 characters. Parsing...
# Retrieving the data on: Powiat lipski
# Retrieved 1423 characters. Parsing...
# Retrieving the data on: Powiat lubaczowski
# Retrieved 1440 characters. Parsing...
# Retrieving the data on: Powiat lubartowski
# Retrieved 1596 characters. Parsing...
# Retrieving the data on: Powiat lubański
# Retrieved 1603 characters. Parsing...
# Retrieving the data on: Powiat lubelski
# Retrieved 1759 characters. Parsing...
# Retrieving the data on: Powiat lubiński
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat lubliniecki
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat lwówecki
# Retrieved 1465 characters. Parsing...
# Retrieving the data on: Powiat lęborski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat lęborski
# Retrieved 1430 characters. Parsing...
# Retrieving the data on: Powiat makowski
# Retrieved 1591 characters. Parsing...
# Retrieving the data on: Powiat malborski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat malborski
# Retrieved 1430 characters. Parsing...
# Retrieving the data on: Powiat miechowski
# Retrieved 1439 characters. Parsing...
# Retrieving the data on: Powiat mielecki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat mielecki
# Retrieved 1431 characters. Parsing...
# Retrieving the data on: Powiat mikołowski
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat milicki
# Retrieved 1603 characters. Parsing...
# Retrieving the data on: Powiat międzychodzki
# Retrieved 1621 characters. Parsing...
# Retrieving the data on: Powiat międzyrzecki
# Retrieved 1605 characters. Parsing...
# Retrieving the data on: Powiat miński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat miński
# Retrieved 1423 characters. Parsing...
# Retrieving the data on: Powiat mogileński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat mogileński
# Retrieved 1616 characters. Parsing...
# Retrieving the data on: Powiat moniecki
# Retrieved 1425 characters. Parsing...
# Retrieving the data on: Powiat mrągowski
# Retrieved 1613 characters. Parsing...
# Retrieving the data on: Powiat myszkowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat myszkowski
# Retrieved 1597 characters. Parsing...
# Retrieving the data on: Powiat myślenicki
# Retrieved 1613 characters. Parsing...
# Retrieving the data on: Powiat myśliborski
# Retrieved 1452 characters. Parsing...
# Retrieving the data on: Powiat mławski
# Retrieved 1423 characters. Parsing...
# Retrieving the data on: Powiat nakielski
# Retrieved 1613 characters. Parsing...
# Retrieving the data on: Powiat namysłowski
# Retrieved 1429 characters. Parsing...
# Retrieving the data on: Powiat nidzicki
# Retrieved 1442 characters. Parsing...
# Retrieving the data on: Powiat niżański
# Retrieved 1596 characters. Parsing...
# Retrieving the data on: Powiat nowodworski (województwo mazowieckie)
# Retrieved 1636 characters. Parsing...
# Retrieving the data on: Powiat nowodworski (województwo pomorskie)
# Retrieved 1466 characters. Parsing...
# Retrieving the data on: Powiat nowomiejski
# Retrieved 1454 characters. Parsing...
# Retrieving the data on: Powiat nowosolski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat nowosolski
# Retrieved 1428 characters. Parsing...
# Retrieving the data on: Powiat nowosądecki
# Retrieved 1774 characters. Parsing...
# Retrieving the data on: Powiat nowotarski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat nowotarski
# Retrieved 1442 characters. Parsing...
# Retrieving the data on: Powiat nowotomyski
# Retrieved 1621 characters. Parsing...
# Retrieving the data on: Powiat nyski
# Retrieved 1411 characters. Parsing...
# Retrieving the data on: Powiat obornicki
# Retrieved 1609 characters. Parsing...
# Retrieving the data on: Powiat olecki
# Retrieved 1607 characters. Parsing...
# Retrieving the data on: Powiat oleski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat oleski
# Retrieved 1417 characters. Parsing...
# Retrieving the data on: Powiat oleśnicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat oleśnicki
# Retrieved 1444 characters. Parsing...
# Retrieving the data on: Powiat olkuski
# Retrieved 1433 characters. Parsing...
# Retrieving the data on: Powiat olsztyński
# Retrieved 1765 characters. Parsing...
# Retrieving the data on: Powiat opatowski
# Retrieved 1582 characters. Parsing...
# Retrieving the data on: Powiat opoczyński
# Retrieved 1424 characters. Parsing...
# Retrieving the data on: Powiat opolski (województwo lubelskie)
# Retrieved 1446 characters. Parsing...
# Retrieving the data on: Powiat opolski (województwo opolskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat opolski (województwo opolskie)
# Retrieved 1731 characters. Parsing...
# Retrieving the data on: Powiat ostrowiecki
# Retrieved 1588 characters. Parsing...
# Retrieving the data on: Powiat ostrowski (województwo mazowieckie)
# Retrieved 1627 characters. Parsing...
# Retrieving the data on: Powiat ostrowski (województwo wielkopolskie)
# Retrieved 1645 characters. Parsing...
# Retrieving the data on: Powiat ostrołęcki
# Retrieved 1787 characters. Parsing...
# Retrieving the data on: Powiat ostrzeszowski
# Retrieved 1450 characters. Parsing...
# Retrieving the data on: Powiat ostródzki
# Retrieved 1613 characters. Parsing...
# Retrieving the data on: Powiat otwocki
# Retrieved 1591 characters. Parsing...
# Retrieving the data on: Powiat oławski
# Retrieved 1435 characters. Parsing...
# Retrieving the data on: Powiat oświęcimski
# Retrieved 1445 characters. Parsing...
# Retrieving the data on: Powiat pabianicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat pabianicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat pabianicki
# Retrieved 1430 characters. Parsing...
# Retrieving the data on: Powiat pajęczański
# Retrieved 1430 characters. Parsing...
# Retrieving the data on: Powiat parczewski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat parczewski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat parczewski
# Retrieved 1590 characters. Parsing...
# Retrieving the data on: Powiat piaseczyński
# Retrieved 1600 characters. Parsing...
# Retrieving the data on: Powiat pilski
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat piotrkowski
# Retrieved 1778 characters. Parsing...
# Retrieving the data on: Powiat piski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat piski
# Retrieved 1433 characters. Parsing...
# Retrieving the data on: Powiat pińczowski
# Retrieved 1588 characters. Parsing...
# Retrieving the data on: Powiat pleszewski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat pleszewski
# Retrieved 1606 characters. Parsing...
# Retrieving the data on: Powiat poddębicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat poddębicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat poddębicki
# Retrieved 1601 characters. Parsing...
# Retrieving the data on: Powiat policki
# Retrieved 1437 characters. Parsing...
# Retrieving the data on: Powiat polkowicki
# Retrieved 1428 characters. Parsing...
# Retrieving the data on: Powiat poznański
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat poznański
# Retrieved 1781 characters. Parsing...
# Retrieving the data on: Powiat proszowicki
# Retrieved 1613 characters. Parsing...
# Retrieving the data on: Powiat prudnicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat prudnicki
# Retrieved 1420 characters. Parsing...
# Retrieving the data on: Powiat pruszkowski
# Retrieved 1600 characters. Parsing...
# Retrieving the data on: Powiat przasnyski
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat przemyski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat przemyski
# Retrieved 1789 characters. Parsing...
# Retrieving the data on: Powiat przeworski
# Retrieved 1608 characters. Parsing...
# Retrieving the data on: Powiat przysuski
# Retrieved 1600 characters. Parsing...
# Retrieving the data on: Powiat pszczyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat pszczyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat pszczyński
# Retrieved 1597 characters. Parsing...
# Retrieving the data on: Powiat pucki
# Retrieved 1421 characters. Parsing...
# Retrieving the data on: Powiat puławski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat puławski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat puławski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat puławski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat puławski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat puławski
# Retrieved 1590 characters. Parsing...
# Retrieving the data on: Powiat pułtuski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat pułtuski
# Retrieved 1429 characters. Parsing...
# Retrieving the data on: Powiat pyrzycki
# Retrieved 1440 characters. Parsing...
# Retrieving the data on: Powiat płocki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat płocki
# Retrieved 1726 characters. Parsing...
# Retrieving the data on: Powiat płoński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat płoński
# Retrieved 1429 characters. Parsing...
# Retrieving the data on: Powiat raciborski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat raciborski
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat radomski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radomski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radomski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radomski
# Retrieved 1757 characters. Parsing...
# Retrieving the data on: Powiat radomszczański
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radomszczański
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radomszczański
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radomszczański
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radomszczański
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radomszczański
# Retrieved 1595 characters. Parsing...
# Retrieving the data on: Powiat radziejowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radziejowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radziejowski
# Retrieved 1625 characters. Parsing...
# Retrieving the data on: Powiat radzyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat radzyński
# Retrieved 1617 characters. Parsing...
# Retrieving the data on: Powiat rawicki
# Retrieved 1435 characters. Parsing...
# Retrieving the data on: Powiat rawski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rawski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rawski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rawski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rawski
# Retrieved 1415 characters. Parsing...
# Retrieving the data on: Powiat ropczycko-sędziszowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat ropczycko-sędziszowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat ropczycko-sędziszowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat ropczycko-sędziszowski
# Retrieved 1473 characters. Parsing...
# Retrieving the data on: Powiat rybnicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rybnicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rybnicki
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rybnicki
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rybnicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rybnicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rybnicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rybnicki
# Retrieved 1763 characters. Parsing...
# Retrieving the data on: Powiat rycki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rycki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rycki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rycki
# Retrieved 1413 characters. Parsing...
# Retrieving the data on: Powiat rypiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rypiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rypiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rypiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rypiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rypiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat rypiński
# Retrieved 1610 characters. Parsing...
# Retrieving the data on: Powiat rzeszowski
# Retrieved 1780 characters. Parsing...
# Retrieving the data on: Powiat sandomierski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat sandomierski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat sandomierski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat sandomierski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat sandomierski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat sandomierski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat sandomierski
# Retrieved 1423 characters. Parsing...
# Retrieving the data on: Powiat sanocki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat sanocki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat sanocki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat sanocki
# Retrieved 1596 characters. Parsing...
# Retrieving the data on: Powiat sejneński
# Retrieved 1422 characters. Parsing...
# Retrieving the data on: Powiat siedlecki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat siedlecki
# Retrieved 1769 characters. Parsing...
# Retrieving the data on: Powiat siemiatycki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat siemiatycki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat siemiatycki
# Retrieved 1608 characters. Parsing...
# Retrieving the data on: Powiat sieradzki
# Retrieved 1592 characters. Parsing...
# Retrieving the data on: Powiat sierpecki
# Retrieved 1591 characters. Parsing...
# Retrieving the data on: Powiat skarżyski
# Retrieved 1591 characters. Parsing...
# Retrieving the data on: Powiat skierniewicki
# Retrieved 1777 characters. Parsing...
# Retrieving the data on: Powiat sochaczewski
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat sokołowski
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat sokólski
# Retrieved 1602 characters. Parsing...
# Retrieving the data on: Powiat stalowowolski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat stalowowolski
# Retrieved 1449 characters. Parsing...
# Retrieving the data on: Powiat starachowicki
# Retrieved 1597 characters. Parsing...
# Retrieving the data on: Powiat stargardzki
# Retrieved 1443 characters. Parsing...
# Retrieving the data on: Powiat starogardzki
# Retrieved 1436 characters. Parsing...
# Retrieving the data on: Powiat staszowski
# Retrieved 1417 characters. Parsing...
# Retrieving the data on: Powiat strzelecki
# Retrieved 1423 characters. Parsing...
# Retrieving the data on: Powiat strzelecko-drezdenecki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat strzelecko-drezdenecki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat strzelecko-drezdenecki
# Retrieved 1455 characters. Parsing...
# Retrieving the data on: Powiat strzeliński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat strzeliński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat strzeliński
# Retrieved 1441 characters. Parsing...
# Retrieving the data on: Powiat strzyżowski
# Retrieved 1443 characters. Parsing...
# Retrieving the data on: Powiat sulęciński
# ...
# Retrieved 1599 characters. Parsing...
# Retrieving the data on: Powiat zamojski
# Retrieved 1745 characters. Parsing...
# Retrieving the data on: Powiat zawierciański
# Retrieved 1432 characters. Parsing...
# Retrieving the data on: Powiat zduńskowolski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat zduńskowolski
# Retrieved 1610 characters. Parsing...
# Retrieving the data on: Powiat zgierski
# Retrieved 1589 characters. Parsing...
# Retrieving the data on: Powiat zgorzelecki
# Retrieved 1444 characters. Parsing...
# Retrieving the data on: Powiat zielonogórski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat zielonogórski
# Retrieved 1760 characters. Parsing...
# Retrieving the data on: Powiat zwoleński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat zwoleński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat zwoleński
# Retrieved 1594 characters. Parsing...
# Retrieving the data on: Powiat ząbkowicki
# Retrieved 1645 characters. Parsing...
# Retrieving the data on: Powiat złotoryjski
# Retrieved 1615 characters. Parsing...
# Retrieving the data on: Powiat złotowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat złotowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat złotowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat złotowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat złotowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat złotowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat złotowski
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat złotowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat złotowski
# Retrieved 1441 characters. Parsing...
# Retrieving the data on: Powiat łaski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łaski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łaski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łaski
# Retrieved 1586 characters. Parsing...
# Retrieving the data on: Powiat łańcucki
# Retrieved 1437 characters. Parsing...
# Retrieving the data on: Powiat łobeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łobeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łobeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łobeski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łobeski
# Retrieved 1437 characters. Parsing...
# Retrieving the data on: Powiat łomżyński
# Retrieved 1596 characters. Parsing...
# Retrieving the data on: Powiat łosicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łosicki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łosicki
# Retrieved 1426 characters. Parsing...
# Retrieving the data on: Powiat łowicki
# Retrieved 1592 characters. Parsing...
# Retrieving the data on: Powiat łukowski
# Retrieved 1422 characters. Parsing...
# Retrieving the data on: Powiat łódzki wschodni
# Retrieved 1439 characters. Parsing...
# Retrieving the data on: Powiat łęczycki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łęczycki
# Retrieved 1598 characters. Parsing...
# Retrieving the data on: Powiat łęczyński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat łęczyński
# Retrieved 1593 characters. Parsing...
# Retrieving the data on: Powiat średzki (województwo dolnośląskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat średzki (województwo dolnośląskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat średzki (województwo dolnośląskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat średzki (województwo dolnośląskie)
# Retrieved 1462 characters. Parsing...
# Retrieving the data on: Powiat średzki (województwo wielkopolskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat średzki (województwo wielkopolskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat średzki (województwo wielkopolskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat średzki (województwo wielkopolskie)
# Retrieved 1642 characters. Parsing...
# Retrieving the data on: Powiat śremski
# Retrieved 1600 characters. Parsing...
# Retrieving the data on: Powiat świdnicki (województwo dolnośląskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo dolnośląskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo dolnośląskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo dolnośląskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo dolnośląskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo dolnośląskie)
# Retrieved 1444 characters. Parsing...
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdnicki (województwo lubelskie)
# Retrieved 1425 characters. Parsing...
# Retrieving the data on: Powiat świdwiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 191 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat świdwiński
# Retrieved 1611 characters. Parsing...
# Retrieving the data on: Powiat świebodziński
# Retrieved 1602 characters. Parsing...
# Retrieving the data on: Powiat świecki
# Retrieved 1451 characters. Parsing...
# Retrieving the data on: Powiat żagański
# Retrieved 1422 characters. Parsing...
# Retrieving the data on: Powiat żarski
# Retrieved 1416 characters. Parsing...
# Retrieving the data on: Powiat żniński
# Retrieved 1442 characters. Parsing...
# Retrieving the data on: Powiat żuromiński
# Retrieved 1429 characters. Parsing...
# Retrieving the data on: Powiat żyrardowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat żyrardowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat żyrardowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat żyrardowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat żyrardowski
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Powiat żyrardowski
# Retrieved 1603 characters. Parsing...
# Retrieving the data on: Powiat żywiecki
# Retrieved 1426 characters. Parsing...
# Retrieving the data on: Poznań
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Poznań
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Poznań
# Retrieved 1746 characters. Parsing...
# Retrieving the data on: Przemyśl
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Przemyśl
# Retrieved 1752 characters. Parsing...
# Retrieving the data on: Płock
# Retrieved 1726 characters. Parsing...
# Retrieving the data on: Radom
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Radom
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Radom
# Retrieved 1724 characters. Parsing...
# Retrieving the data on: Ruda Śląska
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Ruda Śląska
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Ruda Śląska
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Ruda Śląska
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Ruda Śląska
# Retrieved 1744 characters. Parsing...
# Retrieving the data on: Rybnik
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Rybnik
# Retrieved 1729 characters. Parsing...
# Retrieving the data on: Rzeszów
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Rzeszów
# Retrieved 1744 characters. Parsing...
# Retrieving the data on: Siedlce
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Siedlce
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Siedlce
# Retrieved 1734 characters. Parsing...
# Retrieving the data on: Siemianowice Śląskie
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Siemianowice Śląskie
# Retrieved 1789 characters. Parsing...
# Retrieving the data on: Skierniewice
# Retrieved 1737 characters. Parsing...
# Retrieving the data on: Sopot
# Retrieved 1714 characters. Parsing...
# Retrieving the data on: Sosnowiec
# Retrieved 1730 characters. Parsing...
# Retrieving the data on: Suwałki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Suwałki
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Suwałki
# Retrieved 1738 characters. Parsing...
# Retrieving the data on: Szczecin
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Szczecin
# Retrieved 1739 characters. Parsing...
# Retrieving the data on: Słupsk
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Słupsk
# Retrieved 1715 characters. Parsing...
# Retrieving the data on: Tarnobrzeg
# Retrieved 1757 characters. Parsing...
# Retrieving the data on: Tarnów
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Tarnów
# Retrieved 1721 characters. Parsing...
# Retrieving the data on: Toruń
# Retrieved 1748 characters. Parsing...
# Retrieving the data on: Tychy
# Retrieved 1710 characters. Parsing...
# Retrieving the data on: Warszawa
# Retrieved 1719 characters. Parsing...
# Retrieving the data on: Wałbrzych
# Retrieved 1758 characters. Parsing...
# Retrieving the data on: Wrocław
# Retrieved 1751 characters. Parsing...
# Retrieving the data on: Włocławek
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Włocławek
# Retrieved 1770 characters. Parsing...
# Retrieving the data on: Zabrze
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Zabrze
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Zabrze
# Retrieved 1715 characters. Parsing...
# Retrieving the data on: Zamość
# Retrieved 1709 characters. Parsing...
# Retrieving the data on: Zielona Góra
# Retrieved 1741 characters. Parsing...
# Retrieving the data on: Łomża
# Retrieved 1710 characters. Parsing...
# Retrieving the data on: Łódź
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Łódź
# Retrieved 334 characters. Parsing...
# Something went wrong, trying again.
# Retrieving the data on: Łódź
# Retrieved 1718 characters. Parsing...
# Retrieving the data on: Świnoujście
# Retrieved 1758 characters. Parsing...
# Retrieving the data on: Świętochłowice
# Retrieved 1770 characters. Parsing...
# Retrieving the data on: Żory
# Retrieved 1707 characters. Parsing...

# %%
geo_pov # a dictionary of poviats and their geolocation coordinates (polygon-approximated)
# Out:
# {'Biała Podlaska': (52.0387126, 23.1445026),
#  'Białystok': (53.1324886, 23.1688403),
#  'Bielsko-Biała': (49.8223768, 19.0583845),
#  'Bydgoszcz': (53.1234804, 18.0084378),
#  'Bytom': (50.3483816, 18.9157176),
#  'Chełm': (51.1431232, 23.4711986),
#  'Chorzów': (50.2974884, 18.9545728),
#  'Częstochowa': (50.8118195, 19.1203094),
#  'Dąbrowa Górnicza': (50.3216897, 19.1949126),
#  'Elbląg': (54.1560613, 19.4044897),
#  'Gdańsk': (54.3520252, 18.6466384),
#  'Gdynia': (54.5188898, 18.5305409),
#  'Gliwice': (50.2944923, 18.6713802),
#  'Gorzów Wielkopolski': (52.7325285, 15.2369305),
#  'Grudziądz': (53.4837486, 18.7535649),
#  'Jastrzębie-Zdrój': (49.9454207, 18.6101103),
#  'Jaworzno': (50.204987, 19.2739314),
#  'Jelenia Góra': (50.9044171, 15.7193616),
#  'Kalisz': (51.7672799, 18.0853462),
#  'Katowice': (50.2648919, 19.0237815),
#  'Kielce': (50.8660773, 20.6285676),
#  'Konin': (52.2230334, 18.251073),
#  'Koszalin': (54.1943219, 16.1714908),
#  'Kraków': (50.0646501, 19.9449799),
#  'Krosno': (49.6824761, 21.7660531),
#  'Legnica': (51.2070067, 16.1553231),
#  'Leszno': (51.8419861, 16.5937545),
#  'Lublin': (51.2464536, 22.5684463),
#  'Mysłowice': (50.2080466, 19.1660513),
#  'Nowy Sącz': (49.6174535, 20.7153325),
#  'Olsztyn': (53.778422, 20.4801192),
#  'Opole': (50.6751067, 17.9212976),
#  'Ostrołęka': (53.0876544, 21.5592554),
#  'Piekary Śląskie': (50.3789108, 18.9270475),
#  'Piotrków Trybunalski': (51.4051721, 19.7030244),
#  'Powiat aleksandrowski': (52.8153832, 18.7182522),
#  'Powiat augustowski': (53.842919, 23.2073355),
#  'Powiat bartoszycki': (54.2601481, 20.7964826),
#  'Powiat bełchatowski': (51.3657008, 19.2352119),
#  'Powiat bialski': (52.0331887, 23.1298103),
#  'Powiat białobrzeski': (51.6240912, 20.9786982),
#  'Powiat białogardzki': (53.9938442, 16.0579779),
#  'Powiat białostocki': (53.0438238, 23.3148969),
#  'Powiat bielski (województwo podlaskie)': (52.762826, 23.1381261),
#  'Powiat bielski (województwo śląskie)': (49.9080843, 19.076211),
#  'Powiat bieruńsko-lędziński': (50.1078748, 19.1532754),
#  'Powiat bieszczadzki': (49.3098139, 22.6000231),
#  'Powiat biłgorajski': (50.4805711, 22.7841244),
#  'Powiat bocheński': (49.899654, 20.4481946),
#  'Powiat bolesławiecki': (51.3623002, 15.5803488),
#  'Powiat braniewski': (54.3159867, 19.9612973),
#  'Powiat brodnicki': (53.2107481, 19.5570294),
#  'Powiat brzeski (województwo małopolskie)': (49.9670967, 20.6621498),
#  'Powiat brzeski (województwo opolskie)': (50.8245005, 17.5095994),
#  'Powiat brzeziński': (51.8403972, 19.7813314),
#  'Powiat brzozowski': (49.6905132, 21.9880699),
#  'Powiat buski': (50.4263927, 20.8517485),
#  'Powiat bydgoski': (53.118252, 18.0749923),
#  'Powiat bytowski': (54.1454767, 17.3525512),
#  'Powiat będziński': (50.4140948, 19.1132834),
#  'Powiat chełmiński': (53.2951708, 18.5054863),
#  'Powiat chełmski': (51.1368642, 23.4784508),
#  'Powiat chodzieski': (53.0000554, 16.9526472),
#  'Powiat chojnicki': (53.7745398, 17.7291611),
#  'Powiat choszczeński': (53.1388994, 15.6496799),
#  'Powiat chrzanowski': (50.0967994, 19.4651009),
#  'Powiat ciechanowski': (52.8568747, 20.5532001),
#  'Powiat cieszyński': (49.7374201, 18.8311872),
#  'Powiat czarnkowsko-trzcianecki': (52.9079232, 16.3653689),
#  'Powiat częstochowski': (50.798905, 19.1267895),
#  'Powiat człuchowski': (53.7680573, 17.1749251),
#  'Powiat drawski': (53.4667222, 15.8425875),
#  'Powiat działdowski': (53.3050749, 20.050474),
#  'Powiat dzierżoniowski': (50.7717947, 16.7233293),
#  'Powiat dąbrowski': (50.232478, 20.9656068),
#  'Powiat dębicki': (49.9953359, 21.3075494),
#  'Powiat elbląski': (54.01609, 19.5895991),
#  'Powiat ełcki': (53.7888026, 22.3323582),
#  'Powiat garwoliński': (51.8394562, 21.7058361),
#  'Powiat gdański': (54.183493, 18.5707092),
#  'Powiat giżycki': (53.9662624, 21.8876805),
#  'Powiat gliwicki': (50.2874115, 18.6576038),
#  'Powiat gnieźnieński': (52.5014671, 17.628832),
#  'Powiat goleniowski': (53.5954578, 14.8616313),
#  'Powiat golubsko-dobrzyński': (53.1140073, 19.0683907),
#  'Powiat gorlicki': (49.6015013, 21.1285391),
#  'Powiat gorzowski': (52.7256985, 15.2018639),
#  'Powiat gostyniński': (52.4352712, 19.4024278),
#  'Powiat gostyński': (51.8503709, 17.0131816),
#  'Powiat gołdapski': (54.2564043, 22.2855339),
#  'Powiat grajewski': (53.5826026, 22.4521604),
#  'Powiat grodziski (województwo mazowieckie)': (52.0796591, 20.5429688),
#  'Powiat grodziski (województwo wielkopolskie)': (52.210718, 16.332533),
#  'Powiat grudziądzki': (53.4684288, 18.7487561),
#  'Powiat gryficki': (53.9445019, 15.2568565),
#  'Powiat gryfiński': (52.9356926, 14.5010217),
#  'Powiat grójecki': (51.8226058, 20.8597574),
#  'Powiat górowski': (51.663189, 16.5125886),
#  'Powiat głogowski': (51.6574339, 16.096829),
#  'Powiat głubczycki': (50.1746942, 17.8417937),
#  'Powiat hajnowski': (52.7104134, 23.6072363),
#  'Powiat hrubieszowski': (50.7015585, 23.8116511),
#  'Powiat inowrocławski': (52.7947626, 18.2957325),
#  'Powiat iławski': (53.6522976, 19.6031833),
#  'Powiat janowski': (50.7250326, 22.4424755),
#  'Powiat jarociński': (51.9558633, 17.4699972),
#  'Powiat jarosławski': (49.9657776, 22.7535729),
#  'Powiat jasielski': (49.706141, 21.4728496),
#  'Powiat szydłowiecki': (51.2324627, 20.842185),
#  'Powiat sępoleński': (53.4496488, 17.5130857),
#  'Powiat sławieński': (54.3880866, 16.6089643),
#  'Powiat słubicki': (52.3368449, 14.7479227),
#  'Powiat słupecki': (52.2368221, 17.9179392),
#  'Powiat słupski': (54.464148, 17.0284824),
#  'Powiat tarnobrzeski': (50.5798603, 21.6925451),
#  'Powiat tarnogórski': (50.4625163, 18.8263957),
#  'Powiat tarnowski': (50.0366554, 20.9777456),
#  'Powiat tatrzański': (49.3011534, 20.0014575),
#  'Powiat tczewski': (53.8792936, 18.7785139),
#  'Powiat tomaszowski (województwo lubelskie)': (50.4807956, 23.6139646),
#  'Powiat tomaszowski (województwo łódzkie)': (51.6219819, 20.0241625),
#  'Powiat toruński': (53.0299205, 18.6294138),
#  'Powiat trzebnicki': (51.4188443, 16.9985632),
#  'Powiat tucholski': (53.5545868, 17.9946401),
#  'Powiat turecki': (51.9638571, 18.5288506),
#  'Powiat wadowicki': (49.8915953, 19.5413958),
#  'Powiat warszawski zachodni': (52.2738835, 20.6938283),
#  'Powiat wałbrzyski': (50.7593258, 16.2197229),
#  'Powiat wałecki': (53.2355426, 16.234465),
#  'Powiat wejherowski': (54.6303285, 18.0306344),
#  'Powiat wielicki': (49.9412446, 20.2203878),
#  'Powiat wieluński': (51.2402915, 18.6869712),
#  'Powiat wieruszowski': (51.3165967, 18.2184073),
#  'Powiat wodzisławski': (49.9884454, 18.4693241),
#  'Powiat wolsztyński': (52.0666964, 16.117593),
#  'Powiat wołomiński': (52.3635504, 21.2897822),
#  'Powiat wołowski': (51.3910837, 16.6003543),
#  'Powiat wrocławski': (51.1407764, 16.9831788),
#  'Powiat wrzesiński': (52.1944562, 17.6256124),
#  'Powiat wschowski': (51.825543, 16.1333484),
#  'Powiat wysokomazowiecki': (52.8379228, 22.5450705),
#  'Powiat wyszkowski': (52.5960483, 21.4782493),
#  'Powiat wąbrzeski': (53.2897249, 18.9517354),
#  'Powiat wągrowiecki': (52.7845797, 17.2145897),
#  'Powiat węgorzewski': (54.1729496, 21.7636445),
#  'Powiat węgrowski': (52.4242674, 21.906323),
#  'Powiat włocławski': (52.6483303, 19.0677357),
#  'Powiat włodawski': (51.4988572, 23.39179),
#  'Powiat włoszczowski': (50.845232, 19.9790989),
#  'Powiat zambrowski': (53.0024585, 22.2851817),
#  'Powiat zamojski': (50.7220225, 23.2525495),
#  'Powiat zawierciański': (50.4834474, 19.5827637),
#  'Powiat zduńskowolski': (51.654763, 18.9438163),
#  'Powiat zgierski': (51.9025569, 19.4219463),
#  'Powiat zgorzelecki': (51.2488827, 15.1457788),
#  'Powiat zielonogórski': (51.9423914, 15.5208194),
#  'Powiat zwoleński': (51.3354069, 21.5724503),
#  'Powiat ząbkowicki': (50.589523, 16.8122514),
#  'Powiat złotoryjski': (51.1557753, 15.8337662),
#  'Powiat złotowski': (53.4418876, 16.9652247),
#  'Powiat łaski': (51.5468697, 19.066394),
#  'Powiat łańcucki': (50.15712, 22.2392796),
#  'Powiat łobeski': (53.6478187, 15.4845879),
#  'Powiat łomżyński': (53.1734141, 22.047289),
#  'Powiat łosicki': (52.2287911, 22.8868723),
#  'Powiat łowicki': (52.0953911, 19.8347615),
#  'Powiat łukowski': (51.8950983, 22.1028723),
#  'Powiat łódzki wschodni': (51.6705147, 19.6225076),
#  'Powiat łęczycki': (52.1205089, 19.1748072),
#  'Powiat łęczyński': (51.3239456, 22.954777),
#  'Powiat średzki (województwo dolnośląskie)': (51.1369337, 16.5713037),
#  'Powiat średzki (województwo wielkopolskie)': (52.1512246, 17.334844),
#  'Powiat śremski': (52.0096542, 17.113896),
#  'Powiat świdnicki (województwo dolnośląskie)': (50.9003799, 16.4280157),
#  'Powiat świdnicki (województwo lubelskie)': (51.1491241, 22.8386303),
#  'Powiat świdwiński': (53.7796961, 15.8285645),
#  'Powiat świebodziński': (52.2443924, 15.4559136),
#  'Powiat świecki': (53.4958476, 18.3687807),
#  'Powiat żagański': (51.5689064, 15.3245516),
#  'Powiat żarski': (51.6950742, 15.021849),
#  'Powiat żniński': (52.7911685, 17.7536284),
#  'Powiat żuromiński': (53.0672753, 19.8704421),
#  'Powiat żyrardowski': (52.0129718, 20.4227517),
#  'Powiat żywiecki': (49.6089747, 19.2130256),
#  'Poznań': (52.406374, 16.9251681),
#  'Przemyśl': (49.7838623, 22.7677908),
#  'Płock': (52.5463446, 19.7065364),
#  'Radom': (51.4027236, 21.1471334),
#  'Ruda Śląska': (50.2558286, 18.8555704),
#  'Rybnik': (50.1021742, 18.5462847),
#  'Rzeszów': (50.0411867, 21.9991196),
#  'Siedlce': (52.1676031, 22.2901645),
#  'Siemianowice Śląskie': (50.3264314, 19.0295714),
#  'Skierniewice': (51.9547169, 20.1583303),
#  'Sopot': (54.441581, 18.5600956),
#  'Sosnowiec': (50.2862638, 19.1040791),
#  'Suwałki': (54.1115218, 22.9307881),
#  'Szczecin': (53.4285438, 14.5528116),
#  'Słupsk': (54.464148, 17.0284824),
#  'Tarnobrzeg': (50.5729079, 21.6790698),
#  'Tarnów': (50.0121011, 20.9858407),
#  'Toruń': (53.0137902, 18.5984437),
#  'Tychy': (50.1218007, 19.0200023),
#  'Warszawa': (52.2296756, 21.0122287),
#  'Wałbrzych': (50.7840092, 16.2843553),
#  'Wrocław': (51.1078852, 17.0385376),
#  'Włocławek': (52.6483303, 19.0677357),
#  'Zabrze': (50.3249278, 18.7857186),
#  'Zamość': (50.7230879, 23.2519685),
#  'Zielona Góra': (51.9356214, 15.5061862),
#  'Łomża': (53.1781197, 22.0590321),
#  'Łódź': (51.7592485, 19.4559833),
#  'Świnoujście': (53.9100327, 14.2475775),
#  'Świętochłowice': (50.2964328, 18.9171298),
#  'Żory': (50.0447236, 18.7006401)}

# %%
# we need the third DataFrame - poviat names and geolocation
poviats3 = pd.DataFrame(geo_pov).T
poviats3 = poviats3.reset_index()
poviats3.columns = ['Name', 'Latitude', 'Longitude']

# %% [markdown]
# <hr>

# %% [markdown]
# ### 4. Putting it all together

# %% [markdown]
# We now have three datasets from three different sources:<br>
# * <b>poviats1</b> with the data on sports activity (loaded from a local file procured earlier at Statistics Poland),<br>
# * <b>poviats2</b> with the data on population and<br>
# * <b>poviats3</b> with geolocation coordinates of the poviats. We will merge them in two steps, as they carry different poviat naming (see above).

# %%
# combining three datasets into one and preparing the datatypes for plotting
poviats = poviats2.merge(poviats3, how='inner', on='Name')
poviats['Name'] = poviats['Name'].str.replace(r' \(.*\)', '')
poviats = poviats.merge(poviats1, how='inner', on=['Name', 'Voivodship'])
poviats['Population'] = poviats['Population'].astype('int') # we need it as a number now
for yr in yrs:
    poviats[yr] /= poviats['Population'] # we actually need the percentage
# poviats

# %% [markdown]
# ### Visualization

# %% [markdown]
# OK, we have everything ready. Now, let's amaze the world :)

# %% [markdown]
# A brief description of the chart:
#    1. It plots a scatterplot with the blobs representing poviats, laid out geographically
#    2. The radius of the blob represents the poviat population
#    3. The blob's shade represents the regions below (blue shades) or above (red shades) the average
#    4. This indicates regions particularly sporty throughout the years
#    5. The slider allows you to dynamically change the year of observation

# %%
# making the colors and color map representative, adding a slider for the userplay
cmap = plt.cm.bwr
from matplotlib.widgets import Slider

yr = 2016 # default year

fig, ax = plt.subplots()
plt.subplots_adjust(left=0.25, bottom=0.25)

plt.title('POLAND: Share of people active in sports per poviat in {:d}'.format(yr), fontdict={'fontsize': 12})
blobplot = plt.scatter(poviats['Longitude'], poviats['Latitude'], s=poviats['Population']/(500), cmap=cmap, c=poviats[str(int(yr))], alpha=0.5)
_ = plt.scatter([], [], s=0)
blobs = blobplot.get_children()

plt.axis('off')
plt.legend(handles=[blobplot, _], 
           labels=['Radius shows poviat population', 'Color marks sports activity\nBlue is below mean, red is above'],
           markerscale=0.1, frameon=None, loc=0, bbox_to_anchor=(0.5, 0.08), prop={'size': 6})

# building the slider
year_ax = plt.axes([0.28, 0.1, 0.6, 0.02], frameon=False)
year = Slider(year_ax, 'Year', 2002, 2016, valfmt='%d', valinit=2016, valstep=2, color='red', alpha=0.5)

# the update function will redraw the plot each time the slider changes position
def update(val):
    yr = int(year.val)
    plt.sca(ax)
    plt.cla()
    plt.axis('off')
    plt.gca().set_title('POLAND: Share of people active in sports per poviat in {:d}'.format(yr)) # displays the threshold
    blobplot = plt.scatter(poviats['Longitude'], poviats['Latitude'], s=poviats['Population']/(500), cmap=cmap, c=poviats[str(int(yr))], alpha=0.5)
    plt.legend(handles=[blobplot, _],
               labels=['Radius shows poviat population', 'Color marks sports activity\nBlue is below mean, red is above'],
               markerscale=0.1, frameon=None, loc=0, bbox_to_anchor=(0.5, 0.08), prop={'size': 6})
    fig.canvas.draw_idle()

# that sets the trigger
year.on_changed(update)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Seems no doubt that southeastern regions of Poland are and have been really sporty throught the two decades! Only in recent two-four years has the West joined the race :)<br>
# When checking the real world map, one can see that southern parts of Poland are mostly mountainous or hilly at least. That perhaps allows easy access to natural outdoor activity plus makes it more feasible to practise sports, especially winter disciplines like skiing, skijump and such.<br><br>
# That was a helluva task and I enjoyed it. Thank you, Coursera and University of Michigan for this assignment!<br><br>
# Kuba Siekierzyński
